# %% [markdown]
# # Setup system
# Setup the system and get files from the internet.
#
# In the following code, we will download the necessary files from the internet.

# %%
# ??? Need to look at:
#. - Simplify text interface
#  - Simplify the lists



# Remove existing files
import os

# Stop pygame from opening a window
os.environ["SDL_VIDEODRIVER"] = "dummy"

# Install kaleido package
# !pip install -U kaleido

# Mount the drive:
from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/MyDrive/Colab Notebooks")
#!find './' -maxdepth 1 -type f -delete

# Use wget with -nc to avoid overwriting local copy.
# !wget https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py

# Download the pictures:
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Elephant.png
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Squirrel.png
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Tortoise.jpg
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Koala.jpeg

# Import the functions to use
from lineart_v4 import table, simulationVideo, textImage, plotTablesLines, CreateVideo, changeVideoSpeed
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.0 MB/s eta 0:00:00
# ...
# Mounted at /content/drive
# --2025-02-06 17:44:45--  https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30381 (30K) [text/plain]
# Saving to: ‘lineart_v3.py.2’
#
# lineart_v3.py.2     100%[===================>]  29.67K  --.-KB/s    in 0.01s
#
# 2025-02-06 17:44:45 (2.29 MB/s) - ‘lineart_v3.py.2’ saved [30381/30381]
#
# File ‘Elephant.png’ already there; not retrieving.
#
# File ‘Squirrel.png’ already there; not retrieving.
#
# File ‘Tortoise.jpg’ already there; not retrieving.
#
# File ‘Koala.jpeg’ already there; not retrieving.
# ...

# %% [markdown]
# # Tables and object-oriented programming
# In coding, objects are used to save functions and their data for processing.
# We can create an object using a <tt>constructor</tt>.
#
# Here we create a table object to store information using:
# ```
# Elephant = table()
# ```
# We can then store data using:
# ```
# Elephant.column_labels = ["x (hours)", "y (miles)"]
# time_values     = [0, 1, 2, 3, 4, 5]
# distance_values = [0, 1, 2, 3, 4, 5] # <- Speed=1 mile/hour
# Elephant.data_values = [time_values, distance_values]
# ```
# We can see what we stored using <tt>print()</tt>.
#
# However, a nicer way to see the values is to use <tt>plotTable():</tt>
# ```
# Elephant.plotTable()
# ```
# You can save an image using <tt>saveImage()</tt> as shown below:
# ```
# # Create and plot the tyler table first ...
# Elephant.saveImage("Elephant-table.png")
# ```
# This will save the table in the file <tt>tyler.png</tt>.
#
# ## Assignment: Create a table image
# Study the code below.
# Then perform the following:
# 1. Why is the speed 1 mile per hour? Discuss within your group.
# 1. Click on the generated table image and open it.
# 2. Change the file name to <tt>"table.png"</tt>.
# 3. Verify that you can open the new file.

# %%
# Create a table for the Elephant data
Elephant = table()

# Enter the table values:
Elephant.column_labels = ["x (hours)", "y (miles)"]
time_values     = [0, 1, 2, 3, 4, 5]
distance_values = [0, 1, 2, 3, 4, 5]  # <- speed=1 miles per hour
Elephant.data_values = [time_values, distance_values]

# Plot the table
Elephant.plotTable()

# Save the image for the table
Elephant.saveImage("elephant-table.jpg") # <- Can you find this image?

# %% [markdown]
# # Create tables for different speeds
# We want to investigate different speeds.
# ## Assignment
# 1. Squirrel: Change its speed to be 2 miles/hour.
# 2. Tortoise: Change its speed to be 3 miles/hour.
# 3. Koala:    Change its speed to be 4 miles/hour.
# 4. Within your group, discuss what speeds would be more realistic.

# %%
# Create a table for the squirrel data
Squirrel = table()

# Enter the table values:
Squirrel.column_labels = ["x (hours)", "y (miles)"]
time_values     = [0, 1, 2, 3, 4, 5] # <- Why does this remain the same?
distance_values = [0, 1, 2, 3, 4, 5] # <- Change the speed = 2 mile/hour
Squirrel.data_values = [time_values, distance_values]

# Plot the table
Squirrel.plotTable()

# Save the image for the table
Squirrel.saveImage("squirrel-table.jpg") # <- Can you find this image?

# %%
# Create a table for the tortoise data
Tortoise = table()

# Enter the table values:
Tortoise.column_labels = ["x (hours)", "y (miles)"]
time_values     = [0, 1, 2, 3, 4, 5]
distance_values = [0, 1, 2, 3, 4, 5] # <- Change the speed to 3 miles/hour.
Tortoise.data_values = [time_values, distance_values]

# Plot the table
Tortoise.plotTable()

# Save the image for the table
Tortoise.saveImage("tortoise-table.jpg") # <- Find this image

# %%
# Create a table for the koala data
Koala = table()

# Enter the table values:
Koala.column_labels = ["x (hours)", "y (miles)"]
time_values     = [0, 1, 2, 3, 4, 5]
distance_values = [0, 1, 2, 3, 4, 5] # <- Change the speed to 4 miles/hour.
Koala.data_values = [time_values, distance_values]

# Plot the table
Koala.plotTable()

# Save the image for the table
Koala.saveImage("koala-table.jpg") # <- Find this image.

# %% [markdown]
# # Plot multiple tables
# We create a list of all the tables using:
# ```
# tables_list = [Elephant, Squirrel, Tortoise, Koala]
# ```
# You need to enter the corresponding equations in <tt>legend_tables</tt>:
# ```
# # Line equations of tables
# legend_labels = [
#       'Elephant: y = 1*x', # <- Modify the equation here.
#       'Squirrel: y = ?*x', # <- Modify the equation here.
#       'Tortoise: y = ?*x', # <- Modify the equation here.
#       'Koala:    y = ?*x'] # <- Modify the equation here.
# ```
# We finally plot the graph using:
# ```
# plotTablesLines(tables_list,
#                 fig_title = 'Compare speeds',        # title on top
#                 x_label = 'Elapsed time (hours)',    # appears along x-axis
#                 y_label = 'Distance in miles',       # appears along y-axis
#                 legend_title = 'Journey',            # title on the right hand side
#                 legend_labels = legend_labels,       # text describing the table
#                 img_name = 'plot.jpg')               # plot image name
# ```
# This will save the plot in the file <tt>plot.png</tt>.
#
# ## Assignment: Plot multiple tables
# 1. Discuss the code within your group.
# 2. Correct the equations <tt>y=?*x</tt> for each animal.
# 3. Move your cursor over points in the graph. Where do these points come from?
# 3. Discuss the slope of each line. How do they correspond to the equations?
# 3. Who is the slowest? Why?
# 4. Who is the fastest? Why?
# 5. Locate the file <tt>plot.jpg</tt> and click on it.

# %%
# Merge all of the tables
tables_list = [Elephant, Squirrel, Tortoise, Koala]

# Line equations of tables
legend_labels = [
      'Elephant: y = 1*x', # <- Modify the equation here.
      'Squirrel: y = ?*x', # <- Modify the equation here.
      'Tortoise: y = ?*x', # <- Modify the equation here.
      'Koala:    y = ?*x'] # <- Modify the equation here.

# Plot tables
plotTablesLines(tables_list,
                fig_title = 'Compare speeds',        # title on top
                x_label = 'Elapsed time (hours)',    # appears along x-axis
                y_label = 'Distance in miles',       # appears along y-axis
                legend_title = 'Journey',            # title on the right hand side
                legend_labels = legend_labels,       # text describing the table
                img_name = 'plot.jpg')               # plot image name

# %% [markdown]
# # ??? MOUNT REMOTE GOOGLE DRIVE Make videos I: Pick Find character images
# You can use your own images for generating videos. <br>
#
#
# - Each computer has a folder of names.
# - Students must select from images that are given to them.
#
# To do this, search on the internet :-)<br>
# Here is what I searched for in order to find my elephant image:
# ```
#     free cute elephant image facing right on white background
# ```
# You can then upload your images to your local address.
# <b>Careful: You will lose your work if you do not save it locally. </b>
#
# ## Assignment: Find character images
# 1. Make sure to <b>save</b> the Google Colab notebook locally on your directory.
# 2. Make sure to <b>save</b> the images locally on your directory.
# 3. Write down the names of the files that you downloaded.

# %% [markdown]
# ## Upload images to Google Drive
#
# 1. Click on the folder icon on the left of your browser.
#
#
# <b>Folder icon</b>
# ![img1.png](data:image/png;base64,...)
#
# 2. Click on file upload icon to upload your picture.
#
# <b>Upload file icon</b>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Make videos II: Create tables for your characters

# %% [markdown]
# ## Assignment: Create the tables for your characters
#
#
# - Create lists of names, files, and speeds.
# - Use the simplified version.
# - Minimize typing.
#
# 1. Select names for your charaters.
# 2. Modify the code below for the names of your characters.
# 3. Make a note of the names of ALL of the images that you are saving.

# %%
# ??? Remove names here and simplify interface

# Create a table for your first character
# REPLACE elephant with your character's name everywhere here:
Elephant = table() # <- FIX name

Elephant.column_labels = ["x (hours)", "y (miles)"] # <- FIX name and units
time_values     = [0, 1, 2, 3, 4, 5]
distance_values = [0, 1, 2, 3, 4, 5]  # <- FIX speed
Elephant.data_values = [time_values, distance_values] # <- FIX name

Elephant.plotTable() # <- FIX name
Elephant.saveImage("elephant-table.jpg") # <- FIX name and filename


# REPEAT for second character!
Squirrel = table()

Squirrel.column_labels = ["x (hours)", "y (miles)"] # FIX name and units
time_values     = [0, 1, 2, 3, 4, 5] # <- Why does this remain the same?
distance_values = [0, 1, 2, 3, 4, 5] # <- FIX speed
Squirrel.data_values = [time_values, distance_values] # <- FIX

Squirrel.plotTable() # <- FIX
Squirrel.saveImage("squirrel-table.jpg") # <- FIX


# REPEAT for the third character.
Tortoise = table()

Tortoise.column_labels = ["x (hours)", "y (miles)"]
time_values     = [0, 1, 2, 3, 4, 5]
distance_values = [0, 1, 2, 3, 4, 5]
Tortoise.data_values = [time_values, distance_values]

Tortoise.plotTable()
Tortoise.saveImage("tortoise-table.jpg")


# REPEAT for the fourth character.
Koala = table()

Koala.column_labels = ["x (hours)", "y (miles)"]
time_values     = [0, 1, 2, 3, 4, 5]
distance_values = [0, 1, 2, 3, 4, 5]
Koala.data_values = [time_values, distance_values]

Koala.plotTable()
Koala.saveImage("koala-table.jpg")



# Merge all of the tables
tables_list = [Elephant, Squirrel, Tortoise, Koala] # <- FIX names

# Line equations of tables
legend_labels = [
      'Elephant: y = 1*x', # <- Modify name and the equation here.
      'Squirrel: y = ?*x', # <- Modify name and the equation here.
      'Tortoise: y = ?*x', # <- Modify name and the equation here.
      'Koala:    y = ?*x'] # <- Modify name and the equation here.

# Plot tables
plotTablesLines(tables_list,
                fig_title = 'Compare speeds',        # title on top
                x_label = 'Elapsed time (hours)',    # appears along x-axis
                y_label = 'Distance in miles',       # appears along y-axis
                legend_title = 'Journey',            # title on the right hand side
                legend_labels = legend_labels,       # text describing the table
                img_name = 'plot2.jpg')         # <- FIX the plot file name here.

# %% [markdown]
# # Make videos III: Specify names, images, and speeds
# ```
# names  = ["Elephant",     "Squirrel",     "Tortoise",     "Koala"]
# images = ["Elephant.png", "Squirrel.png", "Tortoise.jpg", "Koala.jpeg"]
# speeds = [1,              2,              3,              4]
# ```
# At the end, combine everything:
# ```
# data = [names, images, speeds]
# ```
#
# ## Assignment: place your characters
# 1. Study the code to enter up to 4 characters for your video.
# 2. Delete the code if using less than 4 characters.
# 3. Modify the code as given below. Use realistic speeds!

# %%
# 1. CREATE A SET OF IMAGES for them to select from.
# 2. Simplify text images. Minimize what they type and give max characters.
# 3. Simplify the interface. Use lists.

names  = ["Elephant",     "Squirrel",     "Tortoise",     "Koala"]
images = ["Elephant.png", "Squirrel.png", "Tortoise.jpg", "Koala.jpeg"]
speeds = [1,               2,        3,              4]

data = [names, images, speeds]

# %% [markdown]
# # Make videos IV: Make the video
# Initialize the video:
# ```
# sim_video = simulationVideo(data = data, # characters
#                              duration = 10,            # video duration in seconds
#                              race_distance = 100,      # simulation distance
#                              vid_title = "Race")       # video title
#
# ```
# You can then create and display the video using:
# ```
# video = sim_video.create_video()
# video.ipython_display()
# ```
#
#
# ## Assignment:
# Study the code below and find where the file images are stored.<br>
# Then do the following:
# 1. Click on the file name to view the file.

# %%
# Initialize the video
sim_video = simulationVideo(data = data,            # characters
                             duration = 10,         # video duration in seconds
                             race_distance = 10,    # simulation distance
                             vid_title = "Race")    # video title

# You can then create and display the video using:
video = sim_video.create_video()
video.ipython_display()

# %% [markdown]
# # Make videos V: Experiment with your video
# In the previous run, one hour corresponded to one second of video.
#
# We can make the video go faster by having each second represent two hours.
#
# Tp do this, we can make <tt>simulation_speed=2.0</tt> by running:
# ```
# sim_video.set_video(video_name="new_race.mp4",  # new filename
#                     fps=10,                     # frames per second
#                     simulation_speed=2.0)       # speed of the simulation
# ```
# You can also customize the units (after running set_video) using:
# ```
# sim_video.set_units(distance_string="meters", time_string="seconds", speed_string="meters/second")
# ```
# As before, you can then create and display the video using:
# ```
# video = sim_video.create_video()
# video.ipython_display()
# ```
# ## Assignment: experiment with your video
# 1. Change <tt>simulation_speed</tt> to 2.0. What do you observe?
# 2. Change <tt>fps</tt> to 20. What do you observe?
# 3. Save the video to a different file name.
# 4. Change the distance to feet and the time to minutes.

# %%
# Experiment with the video:
sim_video.set_video(video_name="new_race.mp4",  # new filename
                    fps=10,                     # frames per second
                    simulation_speed=2.0)       # speed of the simulation

sim_video.set_units(distance_string="miles",
                    time_string="hours",
                    speed_string="miles/hour")


# Create and save your video:
video = sim_video.create_video()
video.ipython_display()

# %% [markdown]
# # Make videos VI: Make title and explanatory text images
# You can create many text frames and save them into different frames.<br>
# This is done using <tt>saveImage("filename.png")</tt> as given below:
# ```
# text = """First line.
# Second line.
# Third line."""
# textImage("multi-line.png", text)
# ```
#
# ## Assignment: Create text images
# Study and discuss the code within your group.
# Then perform the following tasks:
# 1. Fill out the different text images.
# 2. Make a note of the names of your images.

# %%
# Create Title and group name here
text = """Your Title
Your Group members' names
"""
textImage("title.png", text)


# ??? DISPLAY the images for debugging.
# ??? Provide full access to placement!
# Provide start location and line spacing control.

# ??? Provide a directory for images *.png and *.jpg
# sorted by creation date.

# ??? Mount external Google Drive location.

# ??? MARIOS: FIX
# Make the distance covered = standard distance

# ENTER the names of your characters.
#  and their corresponding equations.
# cop = constant of proportionality
# cop is the speed for each one.
# x represents time.
# y represents the distance covered.
# NOTE: We only have 7 lines of text in each image.
text = """List equations
Elephant y=?x. ? is cop (K)
Snake    y=?x
"""
textImage("exp1.png", text)

# Victory page
# Who won and why?
text = """Victory page!
Elephant won because ...
"""
textImage("victory.png", text)

text = """This is a very long sentence. And it gets even longer. LONG AND LONG. LONG.
This is a very long sentence. And it gets even longer.
This is a very long sentence. And it gets even longer.
This is a very long sentence. And it gets even longer.
This is a very long sentence. And it gets even longer.
This is a very long sentence. And it gets even longer.
This is a very long sentence. And it gets even longer.
This is a very long sentence. And it gets even longer.
"""
textImage("introduction.png", text)

# %% [markdown]
# # Make videos VII: Make the final video
# You can make the final video by combining images and videos together.
# ```
# img_list = ["multi-line.png",  "plot.jpg", "video.mp4", "tyler.jpg"]
# ```
# Here, note the following:
# - multi-line.png is an image. The file name ends in .png
# - plot.jpg       is an image. The file name ends in .jpg
# - video.mp4      is a video. The file name ends in .mp4
# - tyler.jpg      is an image. The file name ends in .jpg
#
# For the images, we can specify how long to display each one.<br>
# Suppose that we want:
# - 2.0 seconds for multi-line.png.
# - 1.0 seconds for plot.jpg.
# - 1.0         for video.mp4. This number is IGNORED.
# - 1.0 seconds for tyler.jpg.
# We put all of these numbers in a list as given by:
# ```
# durations_list = [2, 1.0, 1.0, 1.0]
# ```
#
# We can now create the video using:
# ```
# video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
#                   file_list=img_list,         # This the list of images and files to combine.
#                   fps=10,                     # The number of frames per second.
#                   durations=durations_list)   # The duration for each one.
# ```
# We can then display the video using:
# ```
# video.ipython_display()
# ```
# ## Assignment: Make final video
# Follow the process to create your final video:
# 1. Determine which images and videos you want to use.
# 2. Determine the order. For example, what is displayed first, second, etc.
# 3. Create the <tt>img_list</tt> array with the file names.
# 4. Determine how many seconds you want to display each image.
# 5. Create the <tt>durations_list</tt> array to enter durations for each image (enter 1 for videos).
# 6. Determine the final video file name.
# 7. Determine the frames per second. Here, note that the fps should match the race video.
# 8. Run <tt>CreateVideo()</tt> and <tt>video.ipython_display()</tt> to debug your video.
# 9. Your video should contain the following:
# - Title and group name
# - Race video
# - All tables
# - Equations
# - Graphs
# - Victory page!

# %%
# Decide which images and videos you want to put together:
# ??? Standardize the names.
# ??? Do not change the names below.
img_list = ["title.png", "introduction.png",  "plot.jpg", "explanation.png", "race.mp4", "winner.png", "victory.png"]

# Set the duration for each one in seconds. Note: video durations are ignored.
# ??? Standardize this also?
# ??? Set it to longer duration for all of them.
durations_list = [2, 2, 1, 1, 1, 1, 1]

# Create the video:
video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
                  file_list=img_list,         # This the list of images and files to combine.
                  fps=10,                     # The number of frames per second.
                  durations=durations_list)   # The duration for each one.

# Display the video:
video.ipython_display()

# %% [markdown]
# # Optional: Change the duration of the entire video
#
# # ??? REMOVE
#
# You can speed up or slow down the final video!
# ```
# changeVideoSpeed("all.mp4", "all2.mp4", speed_factor=0.5)
# ```
# Note:
# - all.mp4  is the input video file.
# - all2.mp4 is a new, output video file.
# - speed_factor=0.5 will double the duration of the video.
# - speed_factor=2.0 will halve the duration of the video.
# - speed_factor=1.0 will not change anything.
# ## Optional Assignment: Change the duration of the entire video.
# Experiment with different speeds to determine which one you prefer.

# %%
changeVideoSpeed("all.mp4", "all2.mp4", speed_factor=0.5)

# %% [markdown]
# # Playing and downloading videos
#
# <b>Video controls</b>
# ![im1.png](data:image/png;base64,...)
#
# <b>Download File after you click on dots icon :</b>
# ![im2.png](data:image/png;base64,...)
