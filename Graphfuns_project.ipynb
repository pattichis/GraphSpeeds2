# %% [markdown]
# <a href="https://colab.research.google.com/github/pattichis/GraphSpeeds2/blob/main/Graphfuns_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Runtime (may require restart)

# %%
# Install old Kaleido that works
# !pip uninstall -y kaleido
# !pip install -q kaleido==0.2.1
# Out:
# WARNING: Skipping kaleido as it is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.1 MB/s eta 0:00:00

# %%
import importlib
import plotly
importlib.reload(plotly)

import plotly.express as px

try:
  fig = px.line(x=[1,2,3], y=[1,4,9], title="Colab Plot")
  fig.write_image("plot.png")
except:
  str = input("Click on Restart Session")

# %% [markdown]
# # Setup

# %% [markdown]
# The following code sets up the system by downloading the library from the web.

# %%
# Remove existing files
import os

os.chdir("/content/")
#!find './' -maxdepth 1 -type f -delete

# Mount the drive:
from google.colab import drive
drive.mount('/content/drive')

# Download the lineart library
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py

# Download the symbolic graphs library.
# !wget 'https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py'


# Import functions for creating videos
from lineart_v3 import table, simulationVideo, textImage, plotTablesLines, CreateVideo, changeVideoSpeed

# Import symbolic plotting functions
from symbolic_graphs2 import graph_funs
import numpy as np

# Import the library:
import sympy as sp

from sympy.interactive.printing import init_printing
init_printing()
# Out:
# Mounted at /content/drive
# --2026-04-17 11:58:29--  https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30381 (30K) [text/plain]
# Saving to: ‘lineart_v3.py’
#
# lineart_v3.py       100%[===================>]  29.67K  --.-KB/s    in 0.003s
#
# 2026-04-17 11:58:29 (9.41 MB/s) - ‘lineart_v3.py’ saved [30381/30381]
#
# --2026-04-17 11:58:29--  https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16371 (16K) [text/plain]
# Saving to: ‘symbolic_graphs2.py’
#
# symbolic_graphs2.py 100%[===================>]  15.99K  --.-KB/s    in 0s
#
# 2026-04-17 11:58:29 (115 MB/s) - ‘symbolic_graphs2.py’ saved [16371/16371]
#
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning:
#
# invalid escape sequence '\P'
#
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning:
#
# "is" with 'str' literal. Did you mean "=="?

# %% [markdown]
# # Make a beautiful flower
#
# 1. Make the first pedal look nice by reducing the domain.
# 2. Create the other pedals. Have fun coloring your pedals.
# 3. After you get the pedals, set hide_axes=True in graph_funs().
# 4. Remove plot.plot_funs() function calls to plot one pedal at a time only.
# 5. Save each pedal into a different picture.
#
# Here is a list of colors:
#    "blue", "green", "red", "cyan", "magenta", "yellow", "black", "white","olive","indigo".

# %%
# MODIFY to add multiple transformations

# Define x as a symbolic variable
x = sp.symbols('x')

# Define exponential function
f1 = 0.25*(2)**(x)

# Create a graph object with equal_axes)
plot = graph_funs(equal_axes=True, hide_axes=False)

# Setup the grid
# Determine the range for X based on reflections and translations.
# Determine the range for Y based on reflections and translations (look at maximum values).
plot.set_XY(minX=-10, maxX=+10, minY=-10, maxY=+10)

# Add to the list of functions:
domain1 = [0.1, 5, 20]

# Plot fun
plot.add_fun(f1, domain1, 'f1(x)='+str(f1), 'red')  # Add the original function.
plot.plot_funs(plot_title="Original function f1 (red)", img_name="frame1.png")

f2 = x
domain2 = [-10, 10, 10]
plot.add_fun(f2, domain2, 'f2', 'black')
plot.plot_funs(plot_title="f1, f2", img_name="frame2.png")

# Add the inverse function.
domain3 = domain1
f3 = plot.add_inverse_fun(f1, domain3, 'inverse of f1', 'green')
plot.plot_funs(plot_title="f1, f2, inverse f1", img_name="frame3.png")

# Flip the inverse function:
f4 = -f3
domain4 = domain1
plot.add_fun(f4, domain4, 'f4', 'blue')
plot.plot_funs(plot_title="f1, f2, f3, f4", img_name="frame4.png")

# Reflect f4:
f5 = f4.subs(x, -x)
domain5 = [-5, -0.1, 20]
plot.add_fun(f5, domain5, 'f5', 'blue')
plot.plot_funs(plot_title="f1, f2, f3, f4, f5", img_name="frame4.png")

# Reflect f5:
f6 = -f5
domain6 = domain5
plot.add_fun(f6, domain6, 'f6', 'blue')
plot.plot_funs(plot_title="f1, f2, f3, f4, f5, f6", img_name="frame4.png")

# Add y=x reflection.
f7 = -x
domain7 = [-10, 10, 20]
plot.add_fun(f7, domain7, 'f7', 'black')
plot.plot_funs(plot_title="f1-f7", img_name="frame4.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="86b2b46e-49c1-48fc-837a-65b908722a91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86b2b46e-49c1-48fc-837a-65b908722a91")) {                    Plotly.newPlot(                        "86b2b46e-49c1-48fc-837a-65b908722a91",                        [{"line":{"color":"red"},"mode":"lines","name":"f1(x)=0.25*2^x","showlegend":true,"x":[0.1,0.35789473684210527,0.6157894736842106,0.8736842105263158,1.1315789473684212,1.3894736842105266,1.6473684210526318,1.905263157894737,2.1631578947368424,2.421052631578948,2.678947368421053,2.936842105263158,3.1947368421052635,3.452631578947369,3.710526315789474,3.9684210526315793,4.226315789473684,4.484210526315789,4.742105263157895,5.0],"y":[0.2679433656340733,0.32038860371802563,0.38309908196261244,0.45808404199596436,0.5477459994326986,0.6549577203939556,0.7831542648379566,0.936443045766318,1.119735430599416,1.3389041012244727,1.6009712145270467,1.9143333920630743,2.2890307475330354,2.737068571689527,3.2728019814519453,3.9133958573730565,4.679374805838512,5.595280766769835,6.690459336559688,8.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6c8ab5b3-06fb-4a6e-a490-0fd906cc6cf6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c8ab5b3-06fb-4a6e-a490-0fd906cc6cf6")) {                    Plotly.newPlot(                        "6c8ab5b3-06fb-4a6e-a490-0fd906cc6cf6",                        [{"line":{"color":"red"},"mode":"lines","name":"f1(x)=0.25*2^x","showlegend":true,"x":[0.1,0.35789473684210527,0.6157894736842106,0.8736842105263158,1.1315789473684212,1.3894736842105266,1.6473684210526318,1.905263157894737,2.1631578947368424,2.421052631578948,2.678947368421053,2.936842105263158,3.1947368421052635,3.452631578947369,3.710526315789474,3.9684210526315793,4.226315789473684,4.484210526315789,4.742105263157895,5.0],"y":[0.2679433656340733,0.32038860371802563,0.38309908196261244,0.45808404199596436,0.5477459994326986,0.6549577203939556,0.7831542648379566,0.936443045766318,1.119735430599416,1.3389041012244727,1.6009712145270467,1.9143333920630743,2.2890307475330354,2.737068571689527,3.2728019814519453,3.9133958573730565,4.679374805838512,5.595280766769835,6.690459336559688,8.0],"type":"scatter"},{"line":{"color":"black"},"mode":"lines","name":"f2","showlegend":true,"x":[-10.0,-7.777777777777778,-5.555555555555555,-3.333333333333333,-1.1111111111111107,1.1111111111111107,3.333333333333334,5.555555555555557,7.777777777777779,10.0],"y":[-10.0,-7.777777777777778,-5.555555555555555,-3.333333333333333,-1.1111111111111107,1.1111111111111107,3.333333333333334,5.555555555555557,7.777777777777779,10.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f17453f4-a21d-4b30-8143-ce4237302b95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f17453f4-a21d-4b30-8143-ce4237302b95")) {                    Plotly.newPlot(                        "f17453f4-a21d-4b30-8143-ce4237302b95",                        [{"line":{"color":"red"},"mode":"lines","name":"f1(x)=0.25*2^x","showlegend":true,"x":[0.1,0.35789473684210527,0.6157894736842106,0.8736842105263158,1.1315789473684212,1.3894736842105266,1.6473684210526318,1.905263157894737,2.1631578947368424,2.421052631578948,2.678947368421053,2.936842105263158,3.1947368421052635,3.452631578947369,3.710526315789474,3.9684210526315793,4.226315789473684,4.484210526315789,4.742105263157895,5.0],"y":
...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d9de3876-5d47-40a7-aee4-8b8f45807199" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9de3876-5d47-40a7-aee4-8b8f45807199")) {                    Plotly.newPlot(                        "d9de3876-5d47-40a7-aee4-8b8f45807199",                        [{"line":{"color":"red"},"mode":"lines","name":"f1(x)=0.25*2^x","showlegend":true,"x":[0.1,0.35789473684210527,0.6157894736842106,0.8736842105263158,1.1315789473684212,1.3894736842105266,1.6473684210526318,1.905263157894737,2.1631578947368424,2.421052631578948,2.678947368421053,2.936842105263158,3.1947368421052635,3.452631578947369,3.710526315789474,3.9684210526315793,4.226315789473684,4.484210526315789,4.742105263157895,5.0],"y":[0.2679433656340733,0.32038860371802563,0.38309908196261244,0.45808404199596436,0.5477459994326986,0.6549577203939556,0.7831542648379566,0.936443045766318,1.119735430599416,1.3389041012244727,1.6009712145270467,1.9143333920630743,2.2890307475330354,2.737068571689527,3.2728019814519453,3.9133958573730565,4.679374805838512,5.595280766769835,6.690459336559688,8.0],"type":"scatter"},{"line":{"color":"black"},"mode":"lines","name":"f2","showlegend":true,"x":[-10.0,-7.777777777777778,-5.555555555555555,-3.333333333333333,-1.1111111111111107,1.1111111111111107,3.333333333333334,5.555555555555557,7.777777777777779,10.0],"y":[-10.0,-7.777777777777778,-5.555555555555555,-3.333333333333333,-1.1111111111111107,1.1111111111111107,3.333333333333334,5.555555555555557,7.777777777777779,10.0],"type":"scatter"},{"line":{"color":"green"},"mode":"lines","name":"inverse of f1","showlegend":true,"x":[0.1,0.35789473684210527,0.6157894736842106,0.8736842105263158,1.1315789473684212,1.3894736842105266,1.6473684210526318,1.905263157894737,2.1631578947368424,2.421052631578948,2.678947368421053,2.936842105263158,3.1947368421052635,3.452631578947369,3.710526315789474,3.9684210526315793,4.226315789473684,4.484210526315789,4.742105263157895,5.0],"y":[-1.3219280948873622,0.5176072329193916,1.3005091112524567,1.8051838230159771,2.1783372412585127,2.474538511027506,2.7201632386016708,2.929990278752258,3.1131389753507355,3.2756344426134274,3.421666237744748,3.5542657034982397,3.6756970979247345,3.787696396287136,3.891623838955208,3.988565104937716,4.079400569186367,4.1648540118948905,4.245527687482591,4.321928094887362],"type":"scatter"},{"line":{"color":"blue"},"mode":"lines","name":"f4","showlegend":true,"x":[0.1,0.35789473684210527,0.6157894736842106,0.8736842105263158,1.1315789473684212,1.3894736842105266,1.6473684210526318,1.905263157894737,2.1631578947368424,2.421052631578948,2.678947368421053,2.936842105263158,3.1947368421052635,3.452631578947369,3.710526315789474,3.9684210526315793,4.226315789473684,4.484210526315789,4.742105263157895,5.0],"y":[1.3219280948873622,-0.5176072329193916,-1.3005091112524567,-1.8051838230159771,-2.1783372412585127,-2.474538511027506,-2.7201632386016708,-2.929990278752258,-3.1131389753507355,-3.2756344426134274,-3.421666237744748,-3.5542657034982397,-3.6756970979247345,-3.787696396287136,-3.891623838955208,-3.988565104937716,-4.079400569186367,-4.1648540118948905,-4.245527687482591,-4.321928094887362],"type":"scatter"},{"line":{"color":"blue"},"mode":"lines","name":"f5","showlegend":true,"x":[-5.0,-4.742105263157895,-4.484210526315789,-4.226315789473684,-3.968421052631579,-3.7105263157894735,-3.4526315789473685,-3.194736842105263,-2.9368421052631577,-2.6789473684210523,-2.421052631578947,-2.163157894736842,-1.9052631578947365,-1.6473684210526311,-1.3894736842105262,-1.1315789473684208,-0.8736842105263154,-0.6157894736842104,-0.3578947368421046,-0.1],"y":[-4.321928094887362,-4.245527687482591,-4.1648540118948905,-4.079400569186367,-3.988565104937716, ...

# %% [markdown]
# # Make a video of your flower growing one pedal at a time
#
# 1. List all of the frames in img_list.
# 2. Give the duration in seconds how long you want each frame to appear.
# 3. Make your video.

# %%
# Create a video

# Decide which images and videos you want to put together:
img_list = ["frame1.png", "frame2.png", "frame3.png", "frame4.png"]

# Set the duration for each one in seconds.
durations_list = [2.0,   # duration for frame1.png
                  2.0,   # frame2.png
                  2.0,   # frame3.png
                  2.0]   # frame4.png

# Create the video:
video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
                  file_list=img_list,         # This the list of images and files to combine.
                  fps=10,                     # The number of frames per second.
                  durations=durations_list)   # The duration for each one.

# Display the video:
video.ipython_display()
# Out:
# Opening  frame1.png
# Opening  frame2.png
# Opening  frame3.png
# Opening  frame4.png
# video: height =  500  width =  700
# The file 'all.mp4' will be created.
# VideoWriter initialized successfully.
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
